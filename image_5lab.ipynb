# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import requests
from io import BytesIO
plt.figure(figsize=(10, 10))
response_cat1 = requests.get('https://avatars.mds.yandex.net/i?id=5847632d1b3b11f2c030e41d0cd44e1172188e41-8554591-images-thumbs&n=13')
img_cat1 = Image.open(BytesIO(response_cat1.content))
plt.imshow(img_cat1);
